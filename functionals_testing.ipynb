# %%
# Using conda env JupyterEnv

from manim import *
from typing import Callable
import numpy as np
import functools

config.pixel_height = 480
config.pixel_width = 854
config.disable_caching = True
config.verbosity = "WARNING"
config.media_embed = True
# Out:
# Manim Community v0.17.3

# %%
from os import PathLike


def test():
    code = Code("Code")


test()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 8
#       4 def test():
#       5     code = Code()
# ----> 8 test()
#
# Cell In[2], line 5, in test()
#       4 def test():
# ----> 5     code = Code()
#
# File d:\Programming\ForkRepos\manim\manim\mobject\text\code_mobject.py:218, in Code.__init__(self, code_file_path, code, language, file_encoding, tab_width, line_spacing, font_size, font, stroke_width, margin, indentation_chars, background, background_stroke_width, background_stroke_color, corner_radius, insert_line_no, line_no_from, line_no_buff, style, generate_html_file, warn_missing_font, **kwargs)
#     216     self.code_string = code
#     217 else:
# --> 218     raise ValueError("Either 'code' or 'code_file_path' arguments must be set")
#     220 """ self._gen_html_string()
#     221 strati = self.html_string.find("background:")
#     222 self.background_color = self.html_string[strati + 12 : strati + 19]
#    (...)
#     287     )
#     288 self.move_to(np.array([0, 0, 0])) """
#
# ValueError: Either 'code' or 'code_file_path' arguments must be set

# %%
class Test(Scene):
    def construct(self):
        self.play(Create(Tex("Test")))
        self.wait(2)

# %%
# %manim Test
# Out:
# <video controls autoplay loop style="max-width: 60%;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
